# %%
import pandas as pd
milk = pd.read_csv('monthly-milk-production.csv',';', index_col=['month'], parse_dates=['month'], dayfirst=True)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot(milk)

# %%
milk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 1962-01-01 to 1975-12-01
# Data columns (total 1 columns):
# milk    168 non-null int64
# dtypes: int64(1)
# memory usage: 2.6 KB

# %%
import statsmodels.api as sm
sm.tsa.stattools.adfuller(milk)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c123eca2aa07> in <module>()
#       1 import statsmodels.api as sm
# ----> 2 sm.tsa.stattools.adfuller(milk)
#
# C:\Users\User\Anaconda2\lib\site-packages\statsmodels\tsa\stattools.pyc in adfuller(x, maxlag, regression, autolag, store, regresults)
#     218
#     219     xdiff = np.diff(x)
# --> 220     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
#     221     nobs = xdall.shape[0]  # pylint: disable=E1103
#     222
#
# C:\Users\User\Anaconda2\lib\site-packages\statsmodels\tsa\tsatools.pyc in lagmat(x, maxlag, trim, original, use_pandas)
#     373     if xa.ndim == 1:
#     374         xa = xa[:, None]
# --> 375     nobs, nvar = xa.shape
#     376     if original in ['ex', 'sep']:
#     377         dropidx = nvar
#
# ValueError: too many values to unpack

# %%
milk_values = []
for i in milk:
    milk_values.append(i)

# %%
import statsmodels.api as sm
sm.graphics.tsa.plot_acf(milk.values.squeeze(), lags=50)

# %%
import statsmodels.api as sm
sm.graphics.tsa.plot_pacf(milk.values.squeeze(), lags=50)

# %%
milk['day_in_month'] = milk.index.days_in_month

# %%
sum(milk['milk']/milk['day_in_month'])
# Out:
# 4166.3266618994639

# %%
import statsmodels.api as sm
sm.tsa.stattools.adfuller(milk['milk'])
# Out:
# (-1.3038115874221301,
#  0.62742670860303129,
#  13,
#  154,
#  {'1%': -3.4735425281962091,
#   '10%': -2.5768780536346769,
#   '5%': -2.880497674144038},
#  1115.1730447395112)
